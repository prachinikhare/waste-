# %%
## Import Libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import keras # to build Neural Network
import pandas as pd
import matplotlib.image as mpimg
import glob, os, random
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# extra
import matplotlib.image as mpimg
from tabulate import tabulate
from sklearn.model_selection import KFold
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
from keras.layers import Conv2D, Flatten, MaxPooling2D, Dense
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from keras import applications
import gc
from skimage import data, io, filters

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
base_path  = '/content/drive/MyDrive/Awareness of Waste Recycling'

classes = os.listdir(base_path)
print(classes)
# Out:
# ['metal', 'e-waste', 'glass', 'plastic', 'light blubs', 'batteries', 'organic', 'clothes', 'paper']

# %%
random.seed(10)
plt.figure(figsize=(20,20))

glass_folder = "/content/drive/MyDrive/Awareness of Waste Recycling/glass"
for i in range(5):
    file = random.choice(os.listdir(glass_folder))
    image_path= os.path.join(glass_folder, file)
    img=mpimg.imread(image_path)
    ax=plt.subplot(1,5,i+1)
    ax.title.set_text(file)
    plt.imshow(img)

# %%
random.seed(10)
plt.figure(figsize=(20,20))

paper_folder = "/content/drive/MyDrive/Awareness of Waste Recycling/paper"
for i in range(5):
    file = random.choice(os.listdir(paper_folder))
    image_path= os.path.join(paper_folder, file)
    img=mpimg.imread(image_path)
    ax=plt.subplot(1,5,i+1)
    ax.title.set_text(file)
    plt.imshow(img)

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  '/content/drive/MyDrive/Awareness of Waste Recycling',
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 7605 files belonging to 9 classes.
# Using 6084 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
 '/content/drive/MyDrive/Awareness of Waste Recycling',
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 7605 files belonging to 9 classes.
# Using 1521 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['batteries', 'clothes', 'e-waste', 'glass', 'light blubs', 'metal', 'organic', 'paper', 'plastic']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.039934594 0.9259013

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs= 8
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/8
# 191/191 [==============================] - 395s 2s/step - loss: 2.0742 - accuracy: 0.2490 - val_loss: 1.9899 - val_accuracy: 0.2604
# Epoch 2/8
# 191/191 [==============================] - 8s 44ms/step - loss: 1.7648 - accuracy: 0.3559 - val_loss: 1.7054 - val_accuracy: 0.3905
# Epoch 3/8
# 191/191 [==============================] - 8s 43ms/step - loss: 1.5116 - accuracy: 0.4579 - val_loss: 1.6380 - val_accuracy: 0.4195
# Epoch 4/8
# 191/191 [==============================] - 8s 43ms/step - loss: 1.2201 - accuracy: 0.5753 - val_loss: 1.6541 - val_accuracy: 0.4694
# Epoch 5/8
# 191/191 [==============================] - 8s 43ms/step - loss: 0.8840 - accuracy: 0.6869 - val_loss: 1.7464 - val_accuracy: 0.4799
# Epoch 6/8
# 191/191 [==============================] - 8s 43ms/step - loss: 0.5743 - accuracy: 0.8064 - val_loss: 1.9875 - val_accuracy: 0.4753
# Epoch 7/8
# 191/191 [==============================] - 8s 43ms/step - loss: 0.3500 - accuracy: 0.8853 - val_loss: 2.4946 - val_accuracy: 0.5023
# Epoch 8/8
# 191/191 [==============================] - 8s 43ms/step - loss: 0.2572 - accuracy: 0.9200 - val_loss: 2.7856 - val_accuracy: 0.4970

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 180, 180, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  flatten_1 (Flatten)         (None, 30976)             0
#
#  dense_2 (Dense)             (None, 128)               3965056
#
#  dense_3 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 60
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/60
# 191/191 [==============================] - 11s 50ms/step - loss: 2.0038 - accuracy: 0.2572 - val_loss: 1.9593 - val_accuracy: 0.3005
# Epoch 2/60
# 191/191 [==============================] - 9s 49ms/step - loss: 1.8279 - accuracy: 0.3330 - val_loss: 1.7297 - val_accuracy: 0.3609
# Epoch 3/60
# 191/191 [==============================] - 9s 49ms/step - loss: 1.6995 - accuracy: 0.3871 - val_loss: 1.6691 - val_accuracy: 0.4043
# Epoch 4/60
# 191/191 [==============================] - 9s 49ms/step - loss: 1.5944 - accuracy: 0.4259 - val_loss: 1.6396 - val_accuracy: 0.4057
# Epoch 5/60
# 191/191 [==============================] - 9s 49ms/step - loss: 1.4872 - accuracy: 0.4683 - val_loss: 1.5638 - val_accuracy: 0.4740
# Epoch 6/60
# 191/191 [==============================] - 9s 49ms/step - loss: 1.4437 - accuracy: 0.4903 - val_loss: 1.5084 - val_accuracy: 0.4767
# Epoch 7/60
# 191/191 [==============================] - 9s 49ms/step - loss: 1.3782 - accuracy: 0.5148 - val_loss: 1.5504 - val_accuracy: 0.4412
# Epoch 8/60
# 191/191 [==============================] - 9s 49ms/step - loss: 1.3146 - accuracy: 0.5398 - val_loss: 1.5669 - val_accuracy: 0.4773
# Epoch 9/60
# 191/191 [==============================] - 9s 49ms/step - loss: 1.2609 - accuracy: 0.5634 - val_loss: 1.4594 - val_accuracy: 0.4938
# Epoch 10/60
# 191/191 [==============================] - 9s 49ms/step - loss: 1.2110 - accuracy: 0.5789 - val_loss: 1.5079 - val_accuracy: 0.5016
# Epoch 11/60
# 191/191 [==============================] - 9s 49ms/step - loss: 1.1533 - accuracy: 0.5996 - val_loss: 1.4673 - val_accuracy: 0.5010
# Epoch 12/60
# 191/191 [==============================] - 9s 49ms/step - loss: 1.1275 - accuracy: 0.6054 - val_loss: 1.4825 - val_accuracy: 0.5003
# Epoch 13/60
# 191/191 [==============================] - 9s 49ms/step - loss: 1.0744 - accuracy: 0.6271 - val_loss: 1.4466 - val_accuracy: 0.5141
# Epoch 14/60
# 191/191 [==============================] - 9s 49ms/step - loss: 1.0332 - accuracy: 0.6468 - val_loss: 1.4645 - val_accuracy: 0.5233
# Epoch 15/60
# 191/191 [==============================] - 9s 49ms/step - loss: 1.0045 - accuracy: 0.6565 - val_loss: 1.5096 - val_accuracy: 0.5240
# Epoch 16/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.9660 - accuracy: 0.6589 - val_loss: 1.4816 - val_accuracy: 0.5417
# Epoch 17/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.9337 - accuracy: 0.6810 - val_loss: 1.4522 - val_accuracy: 0.5634
# Epoch 18/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.8871 - accuracy: 0.6964 - val_loss: 1.4470 - val_accuracy: 0.5634
# Epoch 19/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.8564 - accuracy: 0.7048 - val_loss: 1.5884 - val_accuracy: 0.5306
# Epoch 20/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.8320 - accuracy: 0.7074 - val_loss: 1.4952 - val_accuracy: 0.5654
# Epoch 21/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.7738 - accuracy: 0.7392 - val_loss: 1.6480 - val_accuracy: 0.5582
# Epoch 22/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.7580 - accuracy: 0.7354 - val_loss: 1.5451 - val_accuracy: 0.5529
# Epoch 23/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.7213 - accuracy: 0.7608 - val_loss: 1.5665 - val_accuracy: 0.5490
# Epoch 24/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.7210 - accuracy: 0.7567 - val_loss: 1.5879 - val_accuracy: 0.5536
# Epoch 25/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.6992 - accuracy: 0.7622 - val_loss: 1.5400 - val_accuracy: 0.5766
# Epoch 26/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.6659 - accuracy: 0.7704 - val_loss: 1.6139 - val_accuracy: 0.5720
# Epoch 27/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.6537 - accuracy: 0.7768 - val_loss: 1.6041 - val_accuracy: 0.5661
# Epoch 28/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.6167 - accuracy: 0.7844 - val_loss: 1.5838 - val_accuracy: 0.5845
# Epoch 29/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.6161 - accuracy: 0.7908 - val_loss: 1.6931 - val_accuracy: 0.5549
# Epoch 30/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.5594 - accuracy: 0.8111 - val_loss: 1.8289 - val_accuracy: 0.5312
# Epoch 31/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.5348 - accuracy: 0.8162 - val_loss: 1.6801 - val_accuracy: 0.5884
# Epoch 32/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.5743 - accuracy: 0.8065 - val_loss: 1.6645 - val_accuracy: 0.5700
# Epoch 33/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.5299 - accuracy: 0.8187 - val_loss: 1.7330 - val_accuracy: 0.5805
# Epoch 34/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.5067 - accuracy: 0.8322 - val_loss: 1.7741 - val_accuracy: 0.5779
# Epoch 35/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.5034 - accuracy: 0.8314 - val_loss: 1.7696 - val_accuracy: 0.5733
# Epoch 36/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.4768 - accuracy: 0.8355 - val_loss: 1.7867 - val_accuracy: 0.5878
# Epoch 37/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.4826 - accuracy: 0.8330 - val_loss: 1.8043 - val_accuracy: 0.5911
# Epoch 38/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.4808 - accuracy: 0.8406 - val_loss: 1.7714 - val_accuracy: 0.5924
# Epoch 39/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.4513 - accuracy: 0.8468 - val_loss: 1.9785 - val_accuracy: 0.5792
# Epoch 40/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.4618 - accuracy: 0.8466 - val_loss: 1.8837 - val_accuracy: 0.5792
# Epoch 41/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.4454 - accuracy: 0.8542 - val_loss: 2.0554 - val_accuracy: 0.5805
# Epoch 42/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.4299 - accuracy: 0.8540 - val_loss: 1.9548 - val_accuracy: 0.5845
# Epoch 43/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.4669 - accuracy: 0.8416 - val_loss: 1.9157 - val_accuracy: 0.5858
# Epoch 44/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.3876 - accuracy: 0.8657 - val_loss: 2.2061 - val_accuracy: 0.5694
# Epoch 45/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.3907 - accuracy: 0.8698 - val_loss: 2.1106 - val_accuracy: 0.5851
# Epoch 46/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.3749 - accuracy: 0.8675 - val_loss: 1.9271 - val_accuracy: 0.6128
# Epoch 47/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.3979 - accuracy: 0.8628 - val_loss: 2.0955 - val_accuracy: 0.5891
# Epoch 48/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.3674 - accuracy: 0.8810 - val_loss: 2.1978 - val_accuracy: 0.5773
# Epoch 49/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.3684 - accuracy: 0.8725 - val_loss: 2.1975 - val_accuracy: 0.5838
# Epoch 50/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.3570 - accuracy: 0.8787 - val_loss: 2.1172 - val_accuracy: 0.5878
# Epoch 51/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.3573 - accuracy: 0.8787 - val_loss: 2.0299 - val_accuracy: 0.6055
# Epoch 52/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.3341 - accuracy: 0.8871 - val_loss: 2.2874 - val_accuracy: 0.5661
# Epoch 53/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.3465 - accuracy: 0.8821 - val_loss: 2.1440 - val_accuracy: 0.5917
# Epoch 54/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.3013 - accuracy: 0.8955 - val_loss: 2.2302 - val_accuracy: 0.6121
# Epoch 55/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.3131 - accuracy: 0.8917 - val_loss: 2.0643 - val_accuracy: 0.5904
# Epoch 56/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.3096 - accuracy: 0.8955 - val_loss: 2.1683 - val_accuracy: 0.6174
# Epoch 57/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.3286 - accuracy: 0.8886 - val_loss: 2.1098 - val_accuracy: 0.5983
# Epoch 58/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.2956 - accuracy: 0.9020 - val_loss: 2.2569 - val_accuracy: 0.6101
# Epoch 59/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.2917 - accuracy: 0.9024 - val_loss: 2.2822 - val_accuracy: 0.5930
# Epoch 60/60
# 191/191 [==============================] - 9s 49ms/step - loss: 0.3114 - accuracy: 0.8928 - val_loss: 2.3940 - val_accuracy: 0.5595

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
from tensorflow.keras.preprocessing import image
test_url ="/content/drive/MyDrive/fruits.jpg"
test_path = tf.keras.utils.get_file("/content/drive/MyDrive/fruits.jpg", origin=test_url)

img = tf.keras.utils.load_img(
    test_path, target_size=(img_height, img_width)
)

img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to clothes with a 55.38 percent confidence.

# %%
test_url ="/content/drive/MyDrive/cloths.jfif"
test_path = tf.keras.utils.get_file("/content/drive/MyDrive/cloths.jfif", origin=test_url)

img = tf.keras.utils.load_img(
    test_path, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to clothes with a 80.78 percent confidence.

# %%
test_url ="/content/drive/MyDrive/paper.jfif"
test_path = tf.keras.utils.get_file("/content/drive/MyDrive/paper.jfif", origin=test_url)

img = tf.keras.utils.load_img(
    test_path, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to paper with a 59.48 percent confidence.

# %%
model.save("classifyWaste.h5")
